# %%
import pandas as pd
#import numpy as np
#import matplotlib.pyplot as plt
#import seaborn as sns
#import sklearn
#import scipy.stats
# Out:
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
treino = pd.read_csv('train.csv')

# %%
type(treino)
# Out:
# pandas.core.frame.DataFrame

# %%
type(treino['Name'])
# Out:
# pandas.core.series.Series

# %%
treino.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
treino.Age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
treino.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
treino[treino['Age'] == 76]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
treino.query('Age == 76')
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
def soma_2(idade):
    return idade + 2

# %%
treino.Age.apply(soma_2)
# Out:
# 0      24.0
# 1      40.0
# 2      28.0
# 3      37.0
# 4      37.0
# 5       NaN
# 6      56.0
# 7       4.0
# 8      29.0
# 9      16.0
# 10      6.0
# 11     60.0
# 12     22.0
# 13     41.0
# 14     16.0
# 15     57.0
# 16      4.0
# 17      NaN
# 18     33.0
# 19      NaN
# 20     37.0
# 21     36.0
# 22     17.0
# 23     30.0
# 24     10.0
# 25     40.0
# 26      NaN
# 27     21.0
# 28      NaN
# 29      NaN
#        ...
# 861    23.0
# 862    50.0
# 863     NaN
# 864    26.0
# 865    44.0
# 866    29.0
# 867    33.0
# 868     NaN
# 869     6.0
# 870    28.0
# 871    49.0
# 872    35.0
# 873    49.0
# 874    30.0
# 875    17.0
# 876    22.0
# 877    21.0
# 878     NaN
# 879    58.0
# 880    27.0
# 881    35.0
# 882    24.0
# 883    30.0
# 884    27.0
# 885    41.0
# 886    29.0
# 887    21.0
# 888     NaN
# 889    28.0
# 890    34.0
# Name: Age, Length: 891, dtype: float64

# %%
treino.Age.apply(lambda idade: idade + 2)
# Out:
# 0      24.0
# 1      40.0
# 2      28.0
# 3      37.0
# 4      37.0
# 5       NaN
# 6      56.0
# 7       4.0
# 8      29.0
# 9      16.0
# 10      6.0
# 11     60.0
# 12     22.0
# 13     41.0
# 14     16.0
# 15     57.0
# 16      4.0
# 17      NaN
# 18     33.0
# 19      NaN
# 20     37.0
# 21     36.0
# 22     17.0
# 23     30.0
# 24     10.0
# 25     40.0
# 26      NaN
# 27     21.0
# 28      NaN
# 29      NaN
#        ...
# 861    23.0
# 862    50.0
# 863     NaN
# 864    26.0
# 865    44.0
# 866    29.0
# 867    33.0
# 868     NaN
# 869     6.0
# 870    28.0
# 871    49.0
# 872    35.0
# 873    49.0
# 874    30.0
# 875    17.0
# 876    22.0
# 877    21.0
# 878     NaN
# 879    58.0
# 880    27.0
# 881    35.0
# 882    24.0
# 883    30.0
# 884    27.0
# 885    41.0
# 886    29.0
# 887    21.0
# 888     NaN
# 889    28.0
# 890    34.0
# Name: Age, Length: 891, dtype: float64

# %%
treino.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# 5          False     False   False  False  False   True  False  False   False
# 6          False     False   False  False  False  False  False  False   False
# 7          False     False   False  False  False  False  False  False   False
# 8          False     False   False  False  False  False  False  False   False
# 9          False     False   False  False  False  False  False  False   False
# 10         False     False   False  False  False  False  False  False   False
# ...

# %%
def dados_faltantes(df):
    total = df.isnull().sum().sort_values(ascending=False)
    percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
    dados_faltantes = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
    return dados_faltantes

# %%
dados_faltantes(treino)
# Out:
#              Total   Percent
# Cabin          687  0.771044
# Age            177  0.198653
# Embarked         2  0.002245
# Fare             0  0.000000
# Ticket           0  0.000000
# Parch            0  0.000000
# SibSp            0  0.000000
# Sex              0  0.000000
# Name             0  0.000000
# Pclass           0  0.000000
# Survived         0  0.000000
# PassengerId      0  0.000000

# %%
treino.drop('Cabin', axis=1, inplace=True)

# %%
treino.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
treino = pd.read_csv('train.csv')

# %%
novo_treino = treino.drop('Cabin', axis=1)

# %%
dados_faltantes(novo_treino)
# Out:
#              Total   Percent
# Age            177  0.198653
# Embarked         2  0.002245
# Fare             0  0.000000
# Ticket           0  0.000000
# Parch            0  0.000000
# SibSp            0  0.000000
# Sex              0  0.000000
# Name             0  0.000000
# Pclass           0  0.000000
# Survived         0  0.000000
# PassengerId      0  0.000000

# %%
treino.Cabin.fillna(1, inplace=True)

# %%
dados_faltantes(treino)
# Out:
#              Total   Percent
# Age            177  0.198653
# Embarked         2  0.002245
# Cabin            0  0.000000
# Fare             0  0.000000
# Ticket           0  0.000000
# Parch            0  0.000000
# SibSp            0  0.000000
# Sex              0  0.000000
# Name             0  0.000000
# Pclass           0  0.000000
# Survived         0  0.000000
# PassengerId      0  0.000000

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
corrmat = treino.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.9, square=True)
# Out:
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
treino.Age.fillna(29, inplace=True)

# %%
k = 7
cols = corrmat.nlargest(k, 'Survived')['Survived'].index
cm = np.corrcoef(treino[cols].values.T)
sns.set(font_scale=1.00)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')
sns.set()
cols = ['Survived', 'PassengerId','Pclass', 'Name', 'Sex', 'Age', 'SibSp',
       'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']
sns.pairplot(treino[cols], size=2)
plt.show()
# %matplotlib inline

# %%
treino.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
